# %%
print("Hello World!")

# %%
a = 8

# %%
b = 11

# %%
a+b

# %%
a+b = c
# Out:
#   File "<ipython-input-11-27b161e8bf91>", line 1
#     a+b = c
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a+b=c
# Out:
#   File "<ipython-input-12-a54966cba9f5>", line 1
#     a+b=c
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a = "이승준"
a
# Out:
# '이승준'

# %%
f = 1.414
f
type(f)
# Out:
# float

# %%
type(f)
print(f)
# Out:
# 1.414

# %%
type(f)
# Out:
# float

# %%
type(f)
print(f)
# Out:
# 1.414

# %%
print(type(f))
print(f)
# Out:
# <class 'float'>
# 1.414

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ca730b97bf8a> in <cell line: 1>()
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a
# Out:
# '이승준'
